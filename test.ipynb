-- %%
select * from adb_caresync.silver.insurance_providers

-- %%
select * from adb_caresync.silver.hospitals

-- %%
select * from adb_caresync.bronze.doctors

-- %%
select * from adb_caresync.silver.doctors
